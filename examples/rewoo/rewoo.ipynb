# %% [markdown]
# [이 파일은 이동되었습니다](https://github.com/langchain-ai/langgraph/blob/23961cff61a42b52525f3b20b4094d8d2fba1744/docs/docs/tutorials/rewoo/rewoo.ipynb)

# %% [markdown]
# 이 디렉터리는 순수하게 아카이브 목적으로 유지되며 더 이상 업데이트되지 않습니다. 이전에 이곳에 있던 예제는 새로
# 통합된 [LangChain 문서](https://docs.langchain.com/oss/python/langgraph/overview)로 이동했습니다.
